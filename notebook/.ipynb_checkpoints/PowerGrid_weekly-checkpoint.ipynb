# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
import keras
import h5py
import time
from keras.models import load_model
np.random.seed(21)
# Out:
# Using TensorFlow backend.

# %%
# load data with datetime index
power_data = pd.read_csv('../data/Power grid/Weekly/data.csv', parse_dates=[0])

# sort by date
power_data.sort_values('Date', inplace=True)

# reindex dataframe
power_data.set_index(keys=['Date'], drop=True, inplace=True)
print('='*40)

# check for missing values
print(power_data.isnull().sum())
print('='*40)

# convert 'Change %' column entries to numbers
power_data['Change %'] = power_data['Change %'].apply(lambda x:float(x.split('%')[0]))

def convert(row):
    '''Function for converting volume entries to numbers
    Input: row ---> Row entry; for ex: 5.1M, 8.22K
    Output num ---> Volume in numbers; for ex: 5.1M to 5100000  
    '''
    if row[-1] == 'M':
        num = float(row[:-1])*1000000
    elif row[-1] == 'K':
        num = float(row[:-1])*1000
    elif row[-1] == '-':
        num = 0
    return num

# convert 'Vol.' column entries to numbers
power_data['Vol.'] = power_data['Vol.'].apply(lambda x:convert(x))

power_data.head()
# Out:
# ========================================
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64
# ========================================
#              Price    Open    High    Low         Vol.  Change %
# Date
# 2010-11-07   99.55   97.25  105.25  96.30   57650000.0     -2.45
# 2010-11-14  101.90  100.00  103.25  99.45   21080000.0      2.36
# 2010-11-21   96.45  101.00  101.90  93.30  270250000.0     -5.35
# 2010-11-28   99.80   95.75  100.35  91.80  164810000.0      3.47
# 2010-12-05   96.10  100.00  100.30  94.60   55870000.0     -3.71

# %%
power_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 429 entries, 2010-11-07 to 2019-01-20
# Data columns (total 6 columns):
# Price       429 non-null float64
# Open        429 non-null float64
# High        429 non-null float64
# Low         429 non-null float64
# Vol.        429 non-null float64
# Change %    429 non-null float64
# dtypes: float64(6)
# memory usage: 23.5 KB

# %%
# initialize figure and axes
fig, (ax_1, ax_2, ax_3) = plt.subplots(3,1, figsize=(20,20))

# plot open, close, high and low prices
power_data.plot(y=['Price', 'Open', 'High', 'Low'], ax=ax_1)
ax_1.set_title('Stock Price')
ax_1.set_xlabel('Year')
ax_1.set_ylabel('Price')

# plot volume
power_data.plot(y='Vol.', ax=ax_2)
ax_2.set_title('Stock Volume')
ax_2.set_xlabel('Year')
ax_2.set_ylabel('Volume')

# plot percentage change
power_data.plot(y='Change %', ax=ax_3)
ax_3.set_title('Stock price change percentage')
ax_3.set_xlabel('Year')
ax_3.set_ylabel('Change (%)')

plt.savefig('powergrid_weekly_trends.png')

# %%
# split data
train_data = power_data.iloc[:375,:]
test_data = power_data.iloc[375:,:]

# normalize by splitting into window
window_size = 25
scaler = StandardScaler()

# normalize train data
for di in range(0, len(train_data), window_size):
    scaler.fit(train_data.iloc[di:di+window_size,:])
    train_data.iloc[di:di+window_size,:] = scaler.transform(train_data.iloc[di:di+window_size,:])

# normalize test data
test_data.iloc[:,:] = scaler.transform(test_data.iloc[:,:])

# split into train and test features and targets
X_train, y_train = train_data.iloc[:,1:], train_data.iloc[:,0]
X_test, y_test = test_data.iloc[:,1:], test_data.iloc[:,0]

# %%
X_train.head()
# Out:
#                 Open      High       Low      Vol.  Change %
# Date
# 2010-11-07 -0.575573  1.327952 -0.177426  0.231444 -1.128232
# 2010-11-14  0.419915  0.647997  0.813517 -0.418047  0.981719
# 2010-11-21  0.781911  0.189027 -1.121181  4.007264 -2.400344
# 2010-11-28 -1.118567 -0.337938 -1.593059  2.134628  1.468631
# 2010-12-05  0.419915 -0.354937 -0.712221  0.199831 -1.680942

# %%
X_test.head()
# Out:
#                 Open      High       Low      Vol.  Change %
# Date
# 2018-01-14 -1.880155 -1.896315 -1.727893  1.339752  0.115974
# 2018-01-21 -2.119010 -2.342157 -1.851793  0.160756 -0.301236
# 2018-01-28 -2.357866 -2.450240 -2.456716  2.501936 -0.195613
# 2018-02-04 -3.009290 -2.342157 -2.310951  3.209110  0.269127
# 2018-02-11 -2.401294 -2.058440 -1.829928 -0.436587  0.828927

# %%
y_train.head()
# Out:
# Date
# 2010-11-07    0.051779
# 2010-11-14    0.841920
# 2010-11-21   -0.990534
# 2010-11-28    0.135837
# 2010-12-05   -1.108215
# Name: Price, dtype: float64

# %%
y_test.head()
# Out:
# Date
# 2018-01-14   -1.868476
# 2018-01-21   -2.114256
# 2018-01-28   -2.305419
# 2018-02-04   -2.264455
# 2018-02-11   -1.943576
# Name: Price, dtype: float64

# %%
# initialize model with Keras
model = Sequential()

# add 3 LSTM layers with dropout
model.add(LSTM(input_dim=5, output_dim=10, return_sequences=True))
model.add(Dropout(0.25))

model.add(LSTM(20, return_sequences=True))
model.add(Dropout(0.25))

model.add(LSTM(10, return_sequences=False))
model.add(Dropout(0.25))

# add Dense layer with ReLU activation
model.add(Dense(10,kernel_initializer="uniform",activation='relu'))        

# add Dense layer with Linear activation
model.add(Dense(1,kernel_initializer="uniform",activation='linear'))

# start time
start = time.time()

# compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# model compilation time
print ('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.0488736629486084

# %%
# Fit model on training data with validation data 5% of training data and 150 epochs
model.fit(X_train.values.reshape(X_train.shape[0], 1, X_train.shape[1]),y_train, nb_epoch=150, validation_split=0.05, batch_size=10)
# Out:
# Train on 356 samples, validate on 19 samples
# Epoch 1/150
# 356/356 [==============================] - 5s 14ms/step - loss: 1.0186 - mean_squared_error: 1.0186 - val_loss: 0.6589 - val_mean_squared_error: 0.6589
# Epoch 2/150
# 356/356 [==============================] - 1s 2ms/step - loss: 1.0177 - mean_squared_error: 1.0177 - val_loss: 0.6558 - val_mean_squared_error: 0.6558
# Epoch 3/150
# 356/356 [==============================] - 1s 3ms/step - loss: 1.0041 - mean_squared_error: 1.0041 - val_loss: 0.6144 - val_mean_squared_error: 0.6144
# Epoch 4/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.8958 - mean_squared_error: 0.8958 - val_loss: 0.3572 - val_mean_squared_error: 0.3572
# Epoch 5/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.6207 - mean_squared_error: 0.6207 - val_loss: 0.0785 - val_mean_squared_error: 0.0785
# Epoch 6/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.4232 - mean_squared_error: 0.4232 - val_loss: 0.0588 - val_mean_squared_error: 0.0588
# Epoch 7/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.2864 - mean_squared_error: 0.2864 - val_loss: 0.1055 - val_mean_squared_error: 0.1055
# Epoch 8/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.2362 - mean_squared_error: 0.2362 - val_loss: 0.1547 - val_mean_squared_error: 0.1547
# Epoch 9/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.2198 - mean_squared_error: 0.2198 - val_loss: 0.1420 - val_mean_squared_error: 0.1420
# Epoch 10/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.1884 - mean_squared_error: 0.1884 - val_loss: 0.1341 - val_mean_squared_error: 0.1341
# Epoch 11/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.1698 - mean_squared_error: 0.1698 - val_loss: 0.1327 - val_mean_squared_error: 0.1327
# Epoch 12/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.
150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0878 - mean_squared_error: 0.0878 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 104/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0897 - mean_squared_error: 0.0897 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 105/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0884 - mean_squared_error: 0.0884 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 106/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0911 - mean_squared_error: 0.0911 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 107/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0810 - mean_squared_error: 0.0810 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 108/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 109/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 110/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0875 - mean_squared_error: 0.0875 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 111/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0959 - mean_squared_error: 0.0959 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 112/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0796 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 113/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0783 - mean_squared_error: 0.0783 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 114/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0910 - mean_squared_error: 0.0910 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 115/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 116/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 117/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0863 - mean_squared_error: 0.0863 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 118/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.0312 - val_mean_squared_error: 0.0312
# Epoch 119/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0758 - mean_squared_error: 0.0758 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 120/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0804 - mean_squared_error: 0.0804 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 121/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0880 - mean_squared_error: 0.0880 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 122/150
# 356/356 [==============================] - 1s 2ms/step - loss: 0.0952 - mean_squared_error: 0.0952 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 123/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0771 - mean_squared_error: 0.0771 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 124/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0807 - mean_squared_error: 0.0807 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# Epoch 125/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0888 - mean_squared_error: 0.0888 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 126/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0889 - mean_squared_error: 0.0889 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 127/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0885 - mean_squared_error: 0.0885 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 128/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0815 - mean_squared_error: 0.0815 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 129/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0886 - mean_squared_error: 0.0886 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 130/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0878 - mean_squared_error: 0.0878 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 131/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0810 - mean_squared_error: 0.0810 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 132/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0855 - mean_squared_error: 0.0855 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 133/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0812 - mean_squared_error: 0.0812 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 134/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0783 - mean_squared_error: 0.0783 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 135/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0837 - mean_squared_error: 0.0837 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 136/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0865 - mean_squared_error: 0.0865 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 137/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0742 - mean_squared_error: 0.0742 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 138/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0812 - mean_squared_error: 0.0812 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 139/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0762 - mean_squared_error: 0.0762 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 140/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0883 - mean_squared_error: 0.0883 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 141/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0812 - mean_squared_error: 0.0812 - val_loss: 0.0282 - val_mean_squared_error: 0.0282
# Epoch 142/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 143/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0761 - mean_squared_error: 0.0761 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Epoch 144/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0830 - mean_squared_error: 0.0830 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 145/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0914 - mean_squared_error: 0.0914 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 146/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0878 - mean_squared_error: 0.0878 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 147/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0914 - mean_squared_error: 0.0914 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 148/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0812 - mean_squared_error: 0.0812 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 149/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0868 - mean_squared_error: 0.0868 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 150/150
# 356/356 [==============================] - 1s 3ms/step - loss: 0.0790 - mean_squared_error: 0.0790 - val_loss: 0.0278 - val_mean_squared_error: 0.0278

# %%
# make predictions
y_pred = model.predict(X_test.values.reshape(X_test.shape[0], 1, X_test.shape[1]))

# create copy of original test data to rescale data into original format
test_predictions = test_data.copy()

# set 'Price' feature value as predicted values
test_predictions[['Price']] = y_pred

# inverse transform predictions data
test_predictions.iloc[:,:] = scaler.inverse_transform(test_predictions)
preds = test_predictions.iloc[:,0]

# inverse transform original test data
test_data.iloc[:,:] = scaler.inverse_transform(test_data)
actual = test_data.iloc[:,0]

# %%
preds
# Out:
# Date
# 2018-01-14    198.136906
# 2018-01-21    197.196958
# 2018-01-28    197.019792
# 2018-02-04    197.292384
# 2018-02-11    198.430329
# 2018-02-18    196.878828
# 2018-02-25    199.097790
# 2018-03-04    196.744527
# 2018-03-11    197.197306
# 2018-03-18    197.600890
# 2018-03-25    197.172257
# 2018-04-01    198.541762
# 2018-04-08    198.647414
# 2018-04-15    209.281161
# 2018-04-22    207.690190
# 2018-04-29    205.171513
# 2018-05-06    207.880354
# 2018-05-13    212.592839
# 2018-05-20    211.841196
# 2018-05-27    203.970679
# 2018-06-03    197.965100
# 2018-06-10    198.069091
# 2018-06-17    198.141707
# 2018-06-24    196.377075
# 2018-07-01    196.290212
# 2018-07-08    196.317743
# 2018-07-15    196.216114
# 2018-07-22    196.312696
# 2018-07-29    197.628474
# 2018-08-05    196.891422
# 2018-08-12    196.401330
# 2018-08-19    197.229137
# 2018-08-26    203.277604
# 2018-09-02    197.517204
# 2018-09-09    198.809736
# 2018-09-16    199.411044
# 2018-09-23    196.453545
# 2018-09-30    196.521831
# 2018-10-07    196.495561
# 2018-10-14    196.623057
# 2018-10-21    196.575761
# 2018-10-28    196.592253
# 2018-11-04    196.810963
# 2018-11-11    196.433695
# 2018-11-18    196.264819
# 2018-11-25    196.315482
# 2018-12-02    196.403251
# 2018-12-09    196.348777
# 2018-12-16    202.052138
# 2018-12-23    197.840836
# 2018-12-30    197.662936
# 2019-01-06    197.575340
# 2019-01-13    197.312190
# 2019-01-20    196.446321
# Name: Price, dtype: float64

# %%
actual
# Out:
# Date
# 2018-01-14    196.10
# 2018-01-21    194.30
# 2018-01-28    192.90
# 2018-02-04    193.20
# 2018-02-11    195.55
# 2018-02-18    193.25
# 2018-02-25    197.40
# 2018-03-04    192.90
# 2018-03-11    192.25
# 2018-03-18    194.25
# 2018-03-25    193.25
# 2018-04-01    195.95
# 2018-04-08    197.50
# 2018-04-15    207.20
# 2018-04-22    207.90
# 2018-04-29    207.40
# 2018-05-06    206.85
# 2018-05-13    212.95
# 2018-05-20    212.05
# 2018-05-27    205.95
# 2018-06-03    197.90
# 2018-06-10    197.85
# 2018-06-17    197.70
# 2018-06-24    186.85
# 2018-07-01    181.80
# 2018-07-08    181.75
# 2018-07-15    175.80
# 2018-07-22    179.90
# 2018-07-29    190.20
# 2018-08-05    190.55
# 2018-08-12    187.10
# 2018-08-19    190.95
# 2018-08-26    201.50
# 2018-09-02    195.70
# 2018-09-09    200.15
# 2018-09-16    200.40
# 2018-09-23    188.40
# 2018-09-30    187.30
# 2018-10-07    188.45
# 2018-10-14    189.15
# 2018-10-21    188.40
# 2018-10-28    189.85
# 2018-11-04    191.70
# 2018-11-11    188.10
# 2018-11-18    179.80
# 2018-11-25    180.15
# 2018-12-02    182.65
# 2018-12-09    185.70
# 2018-12-16    196.90
# 2018-12-23    197.05
# 2018-12-30    195.90
# 2019-01-06    194.35
# 2019-01-13    193.60
# 2019-01-20    187.40
# Name: Price, dtype: float64

# %%
# calculate mean squared error on test data
error = np.sqrt(mean_squared_error(preds, actual))
print(error)
# Out:
# 7.501334933826275

# %%
# comapre original vs predicted stock prices
plt.figure(figsize=(20,10))
plt.plot(actual, color='green')
plt.plot(preds, color='black')
plt.legend(['Actual Price', 'Predicted Price'])
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Predicted vs Actual Stock Price')
plt.savefig('powergrid_weekly.png')

# %%
comp = pd.DataFrame({'Actual':actual, 'Predicted':preds}, index=actual.index)
comp.head()
# Out:
#             Actual   Predicted
# Date
# 2018-01-14  196.10  198.136906
# 2018-01-21  194.30  197.196958
# 2018-01-28  192.90  197.019792
# 2018-02-04  193.20  197.292384
# 2018-02-11  195.55  198.430329

# %%
comp.to_csv('powergrid_weekly.csv')
