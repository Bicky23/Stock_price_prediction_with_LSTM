# %% [markdown]
# ## COAL India Ltd. stock price prediction (Daily)
#
# LSTM used to predict the stock price for COAL India Ltd. based on daily data.
#
# **Programming language**: Python 3
#
# **Framework used**: Keras with TensorFlow backend

# %% [markdown]
# ## Import libraries

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
import keras
import h5py
import time
from keras.models import load_model
np.random.seed(21)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocess data
#
# **Steps**
#
# - Load data with datetime format
# - Sort values by date since it is time series data
# - Initial entries for `'Change %'` and `'Vol.'` are in object mode; converted to numbers

# %%
# load data with datetime index
coal_data = pd.read_csv('../data/COAL India/Daily/data.csv', parse_dates=[0])

# sort by date
coal_data.sort_values('Date', inplace=True)

# reindex dataframe
coal_data.set_index(keys=['Date'], drop=True, inplace=True)
print('='*40)

# check for missing values
print(coal_data.isnull().sum())
print('='*40)

# convert 'Change %' column entries to numbers
coal_data['Change %'] = coal_data['Change %'].apply(lambda x:float(x.split('%')[0]))

def convert(row):
    '''Function for converting volume entries to numbers
    Input: row ---> Row entry; for ex: 5.1M, 8.22K
    Output num ---> Volume in numbers; for ex: 5.1M to 5100000  
    '''
    if row[-1] == 'M':
        num = float(row[:-1])*1000000
    elif row[-1] == 'K':
        num = float(row[:-1])*1000
    elif row[-1] == '-':
        num = 0
    return num

# convert 'Vol.' column entries to numbers
coal_data['Vol.'] = coal_data['Vol.'].apply(lambda x:convert(x))

coal_data.head()
# Out:
# ========================================
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64
# ========================================
#              Price    Open    High     Low        Vol.  Change %
# Date
# 2010-11-05  349.65  350.00  357.60  345.10  12310000.0      2.13
# 2010-11-08  330.45  351.00  355.70  330.00  16200000.0     -5.49
# 2010-11-09  326.05  330.45  333.30  325.25   6290000.0     -1.33
# 2010-11-10  322.55  327.00  328.25  320.05   7170000.0     -1.07
# 2010-11-11  328.45  323.45  336.65  322.00   8850000.0      1.83

# %%
coal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2035 entries, 2010-11-05 to 2019-01-21
# Data columns (total 6 columns):
# Price       2035 non-null float64
# Open        2035 non-null float64
# High        2035 non-null float64
# Low         2035 non-null float64
# Vol.        2035 non-null float64
# Change %    2035 non-null float64
# dtypes: float64(6)
# memory usage: 111.3 KB

# %% [markdown]
# ## Visualize trends
#
# It helps to look for seasonality in the data

# %%
# initialize figure and axes
fig, (ax_1, ax_2, ax_3) = plt.subplots(3,1, figsize=(20,20))

# plot open, close, high and low prices
coal_data.plot(y=['Price', 'Open', 'High', 'Low'], ax=ax_1)
ax_1.set_title('Stock Price')
ax_1.set_xlabel('Year')
ax_1.set_ylabel('Price')

# plot volume
coal_data.plot(y='Vol.', ax=ax_2)
ax_2.set_title('Stock Volume')
ax_2.set_xlabel('Year')
ax_2.set_ylabel('Volume')

# plot percentage change
coal_data.plot(y='Change %', ax=ax_3)
ax_3.set_title('Stock price change percentage')
ax_3.set_xlabel('Year')
ax_3.set_ylabel('Change (%)')

plt.savefig('coal_daily_trends.png')
# plt.show()

# %%
coal_data.head()
# Out:
#              Price    Open    High     Low        Vol.  Change %
# Date
# 2010-11-05  349.65  350.00  357.60  345.10  12310000.0      2.13
# 2010-11-08  330.45  351.00  355.70  330.00  16200000.0     -5.49
# 2010-11-09  326.05  330.45  333.30  325.25   6290000.0     -1.33
# 2010-11-10  322.55  327.00  328.25  320.05   7170000.0     -1.07
# 2010-11-11  328.45  323.45  336.65  322.00   8850000.0      1.83

# %%
coal_data.shape
# Out:
# (2035, 6)

# %% [markdown]
# ## Normalize with window method and split into training and test
#
# - Training data is 88% and test data is 12%
# - Training data is standardized with a window size of 25 with zero mean and unit standard deviation. Accordingly, test data is also standardized

# %%
# split data
train_data = coal_data.iloc[:1800,:]
test_data = coal_data.iloc[1800:,:]

# normalize by splitting into window
window_size = 25
scaler = StandardScaler()

# normalize train data
for di in range(0, len(train_data), window_size):
    scaler.fit(train_data.iloc[di:di+window_size,:])
    train_data.iloc[di:di+window_size,:] = scaler.transform(train_data.iloc[di:di+window_size,:])

# normalize test data
test_data.iloc[:,:] = scaler.transform(test_data.iloc[:,:])

# split into train and test features and targets
X_train, y_train = train_data.iloc[:,1:], train_data.iloc[:,0]
X_test, y_test = test_data.iloc[:,1:], test_data.iloc[:,0]

# %%
X_train.head()
# Out:
#                 Open      High       Low      Vol.  Change %
# Date
# 2010-11-05  2.662400  2.805877  3.057756  2.007154  1.239603
# 2010-11-08  2.764958  2.624260  1.365106  2.986068 -2.662320
# 2010-11-09  0.657395  0.483099  0.832650  0.492228 -0.532136
# 2010-11-10  0.303571  0.000382  0.249750  0.713679 -0.399000
# 2010-11-11 -0.060509  0.803318  0.468337  1.136449  1.085984

# %%
X_test.head()
# Out:
#                 Open      High       Low      Vol.  Change %
# Date
# 2018-02-07  0.048485  0.521615  0.213238  0.212977  1.038215
# 2018-02-08  0.286729  0.448379  0.711415 -0.635415  0.192539
# 2018-02-09  0.453919  0.616392 -0.033522  1.032689 -0.122131
# 2018-02-12  0.788297  0.681012  0.804532  2.642301 -0.220466
# 2018-02-14  0.784117  1.038578  1.102507 -0.217818  1.033299

# %%
y_train.head()
# Out:
# Date
# 2010-11-05    3.335033
# 2010-11-08    1.018535
# 2010-11-09    0.487671
# 2010-11-10    0.065393
# 2010-11-11    0.777233
# Name: Price, dtype: float64

# %%
y_test.head()
# Out:
# Date
# 2018-02-07    0.461811
# 2018-02-08    0.669959
# 2018-02-09    0.702337
# 2018-02-12    0.679210
# 2018-02-14    1.363785
# Name: Price, dtype: float64

# %% [markdown]
# ## Model Building with LSTM using Keras
#
# - LSTM model with 4 hidden layers
# - First 3 hidden layers are LSTM layers with 10, 20 and 10 neurons. Final hidden layer is a dense one with 10 neurons
# - Output layer is a dense layer with single output predicting the stock value
# - Use of dropout (to prevent overfitting) with ReLU activation in hidden layers and linear activation in the output layer
# - Optimizer used is Adam with Mean Squared Error (MSE) as the loss to minimize
# - Weights are initialized randomly within the network
# - Model is trained on 95% of training data and validated of rest 5% of it. Total passes/epochs is 150

# %%
# initialize model with Keras
model = Sequential()

# add 3 LSTM layers with dropout
model.add(LSTM(input_dim=5, output_dim=10, return_sequences=True))
model.add(Dropout(0.1))

model.add(LSTM(20, return_sequences=True))
model.add(Dropout(0.1))

model.add(LSTM(10, return_sequences=False))
model.add(Dropout(0.1))

# add Dense layer with ReLU activation
model.add(Dense(10,kernel_initializer="uniform",activation='relu'))        

# add Dense layer with Linear activation
model.add(Dense(1,kernel_initializer="uniform",activation='linear'))

# start time
start = time.time()

# compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# model compilation time
print ('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.051966190338134766

# %%
# Fit model on training data with validation data 5% of training data and 150 epochs
model.fit(X_train.values.reshape(X_train.shape[0], 1, X_train.shape[1]),y_train, nb_epoch=150, validation_split=0.05, batch_size=40)
# Out:
# Train on 1710 samples, validate on 90 samples
# Epoch 1/150
# 1710/1710 [==============================] - 5s 3ms/step - loss: 1.0008 - mean_squared_error: 1.0008 - val_loss: 0.9785 - val_mean_squared_error: 0.9785
# Epoch 2/150
# 1710/1710 [==============================] - 1s 452us/step - loss: 0.9854 - mean_squared_error: 0.9854 - val_loss: 0.9290 - val_mean_squared_error: 0.9290
# Epoch 3/150
# 1710/1710 [==============================] - 1s 683us/step - loss: 0.8060 - mean_squared_error: 0.8060 - val_loss: 0.5662 - val_mean_squared_error: 0.5662
# Epoch 4/150
# 1710/1710 [==============================] - 1s 590us/step - loss: 0.3763 - mean_squared_error: 0.3763 - val_loss: 0.2242 - val_mean_squared_error: 0.2242
# Epoch 5/150
# 1710/1710 [==============================] - 1s 634us/step - loss: 0.2052 - mean_squared_error: 0.2052 - val_loss: 0.1338 - val_mean_squared_error: 0.1338
# Epoch 6/150
# 1710/1710 [==============================] - 1s 571us/step - loss: 0.1528 - mean_squared_error: 0.1528 - val_loss: 0.1056 - val_mean_squared_error: 0.1056
# Epoch 7/150
# 1710/1710 [==============================] - 1s 608us/step - loss: 0.1294 - mean_squared_error: 0.1294 - val_loss: 0.0876 - val_mean_squared_error: 0.0876
# Epoch 8/150
# 1710/1710 [==============================] - 1s 597us/step - loss: 0.1098 - mean_squared_error: 0.1098 - val_loss: 0.0742 - val_mean_squared_error: 0.0742
# Epoch 9/150
# 1710/1710 [==============================] - 1s 597us/step - loss: 0.0958 - mean_squared_error: 0.0958 - val_loss: 0.0647 - val_mean_squared_error: 0.0647
# Epoch 10/150
# 1710/1710 [==============================] - 1s 533us/step - loss: 0.0821 - mean_squared_error: 0.0821 - val_loss: 0.0573 - val_mean_squared_error: 0.0573
# Epoch 11/150
# 1710/1710 [==============================] - 1s 527us/step - loss: 0.0755 - mean_squared_error: 0.0755 - val_loss: 0.0551 - val_mean_squared_error: 0.0551
# Epoch 12/150
# 1710/1710 [==============================] - 1s 583us/step - loss: 0.0723 - mean_squared_error: 0.0723 - val_loss: 0.0538 - val_mean_squared_error: 0.0538
# Epoch 13/150
# 1710/1710 [==============================] - 1s 607us/step - loss: 0.0689 - mean_squared_error: 0.0689 - val_loss: 0
loss: 0.0471 - mean_squared_error: 0.0471 - val_loss: 0.0451 - val_mean_squared_error: 0.0451
# Epoch 136/150
# 1710/1710 [==============================] - 1s 744us/step - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.0477 - val_mean_squared_error: 0.0477
# Epoch 137/150
# 1710/1710 [==============================] - 1s 817us/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0463 - val_mean_squared_error: 0.0463
# Epoch 138/150
# 1710/1710 [==============================] - 1s 800us/step - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0461 - val_mean_squared_error: 0.0461
# Epoch 139/150
# 1710/1710 [==============================] - 1s 772us/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0482 - val_mean_squared_error: 0.0482
# Epoch 140/150
# 1710/1710 [==============================] - 1s 691us/step - loss: 0.0515 - mean_squared_error: 0.0515 - val_loss: 0.0458 - val_mean_squared_error: 0.0458
# Epoch 141/150
# 1710/1710 [==============================] - 1s 537us/step - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0465 - val_mean_squared_error: 0.0465
# Epoch 142/150
# 1710/1710 [==============================] - 1s 544us/step - loss: 0.0499 - mean_squared_error: 0.0499 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
# Epoch 143/150
# 1710/1710 [==============================] - 1s 527us/step - loss: 0.0481 - mean_squared_error: 0.0481 - val_loss: 0.0452 - val_mean_squared_error: 0.0452
# Epoch 144/150
# 1710/1710 [==============================] - 1s 671us/step - loss: 0.0482 - mean_squared_error: 0.0482 - val_loss: 0.0425 - val_mean_squared_error: 0.0425
# Epoch 145/150
# 1710/1710 [==============================] - 1s 691us/step - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.0489 - val_mean_squared_error: 0.0489
# Epoch 146/150
# 1710/1710 [==============================] - 1s 597us/step - loss: 0.0484 - mean_squared_error: 0.0484 - val_loss: 0.0447 - val_mean_squared_error: 0.0447
# Epoch 147/150
# 1710/1710 [==============================] - 1s 662us/step - loss: 0.0483 - mean_squared_error: 0.0483 - val_loss: 0.0455 - val_mean_squared_error: 0.0455
# Epoch 148/150
# 1710/1710 [==============================] - 1s 663us/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.0437 - val_mean_squared_error: 0.0437
# Epoch 149/150
# 1710/1710 [==============================] - 1s 664us/step - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0443 - val_mean_squared_error: 0.0443
# Epoch 150/150
# 1710/1710 [==============================] - 1s 670us/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0462 - val_mean_squared_error: 0.0462

# %% [markdown]
# ## Making predictions with LSTM
# - Predicted stock prices are scaled back to original scale

# %%
# make predictions
y_pred = model.predict(X_test.values.reshape(X_test.shape[0], 1, X_test.shape[1]))

# create copy of original test data to rescale data into original format
test_predictions = test_data.copy()

# set 'Price' feature value as predicted values
test_predictions[['Price']] = y_pred

# inverse transform predictions data
test_predictions.iloc[:,:] = scaler.inverse_transform(test_predictions)
preds = test_predictions.iloc[:,0]

# inverse transform original test data
test_data.iloc[:,:] = scaler.inverse_transform(test_data)
actual = test_data.iloc[:,0]

# %% [markdown]
# ## Calculating Root Mean-Squared-Error on test data

# %%
# calculate mean squared error on test data
error = np.sqrt(mean_squared_error(preds, actual))
print(error)
# Out:
# 7.542162235212948

# %% [markdown]
# ## Comparing original and predicted prices

# %%
# comapre original vs predicted stock prices
plt.figure(figsize=(20,10))
plt.plot(actual, color='green')
plt.plot(preds, color='black')
plt.legend(['Actual Price', 'Predicted Price'])
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Predicted vs Actual Stock Price')
plt.savefig('coal_daily.png')
# plt.show()

# %% [markdown]
# ## Save it to CSV file

# %%
comp = pd.DataFrame({'Actual':actual, 'Predicted':preds}, index=actual.index)
comp.head()
# Out:
#             Actual   Predicted
# Date
# 2018-02-07  297.85  300.359508
# 2018-02-08  300.10  299.609366
# 2018-02-09  300.45  296.269360
# 2018-02-12  300.20  300.460343
# 2018-02-14  307.60  307.262846

# %%
comp.to_csv('coal_daily.csv')
